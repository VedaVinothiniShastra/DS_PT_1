# %% [markdown]
# Visualization with Seaborn
#     Seaborn Versus Matplotlib
# 	Exploring Seaborn Plots
# 	Exploring Marathon Finishing Times - mini proj

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y= np.sin(x)
plt.plot(x,y)

# %%
#seaborn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y= np.sin(x)
sb.set()
plt.plot(x,y)

# %%
#Exploring Seaborn Plots -> hist , kde , density
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])
for col in 'xy':
    plt.hist(data[col], alpha=0.5)

# %%
#kde: kernel density estimate
import seaborn as sb
for col in 'xy':
    sb.kdeplot(data[col], shade=True)
# Out:
# C:\Users\bjawa\AppData\Local\Temp\ipykernel_35696\604538941.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sb.kdeplot(data[col], shade=True)
# C:\Users\bjawa\AppData\Local\Temp\ipykernel_35696\604538941.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sb.kdeplot(data[col], shade=True)

# %%
#adding two plots hist + kde
sb.distplot(data['x'])
sb.distplot(data['y'])
# Out:
# C:\Users\bjawa\AppData\Local\Temp\ipykernel_35696\689164505.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(data['x'])
# C:\Users\bjawa\AppData\Local\Temp\ipykernel_35696\689164505.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(data['y'])
# ...

# %%
# kdeplot

sb.kdeplot(data)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
#joinplot
with sb.axes_style('white'):
    sb.jointplot( data, kind='kde');

# %%
#pair plots

i =sb.load_dataset('iris')
print(i)
sb.pairplot(i, hue='species', size=2.5);
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# ...

# %%
#Faceted histograms -> facegrid

tips=sb.load_dataset('tips')
print(tips)
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']
grid = sb.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15));
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#factor plot / catplot

with sb.axes_style(style='ticks'):
    g = sb.catplot( data=tips, kind="box")
    g.set_axis_labels("Day", "Total Bill");

# %%
with sb.axes_style('white'):
    sb.jointplot(data=tips)

# %%
#importing 

planets = sb.load_dataset('planets')
print(planets)
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
#input

#https://raw.githubusercontent.com/jakevdp/marathon-data/master/marathon-data.csv

a=pd.read_csv('marathon-data.csv')
print(a)
# Out:
#        age gender     split     final
# 0       33      M  01:05:38  02:08:51
# 1       32      M  01:06:26  02:09:28
# 2       31      M  01:06:49  02:10:42
# 3       38      M  01:06:16  02:13:45
# 4       31      M  01:06:32  02:13:59
# ...    ...    ...       ...       ...
# 37245   18      M  04:24:24  09:32:57
# 37246   36      M  04:35:43  09:33:28
# 37247   51      M  04:22:35  09:33:40
# 37248   55      W  04:58:06  10:00:40
# 37249   58      W  04:59:49  10:01:08
#
# [37250 rows x 4 columns]

# %% [markdown]
# Machine Learning
#     What Is Machine Learning? -> refer day 1 doc
# 	Categories of Machine Learning -> super  (classification, regression), unsuper(clustering & dimestionality redu) , reinforcement
# 	Qualitative Examples of Machine Learning Applications

# %% [markdown]
# Machine learning :
# ->It is a study of Computer algorithms
# ->It will get improved by use of data and experience
# Eg:
# 1.Supervised learning: I/p -> Target o/p
# Student 1- > Syllabus -> Exam(only syllabus)
# 2.Unsupervised Learning : I/p -> Donot know target o/p
# Student 1- > Syllabus eg: a & b =c -> Exam(out of syllabus / p & q =?)
# 3.Reinforcement Learning: It learn from mistakes and answer
# Student 1- > Syllabus eg: a & b =c -> Exam(out of syllabus / p & q =r) =->Learning concept /syllabus
# p& q = r -> Correct
# p& q =4 -> In correct
#
#
#
# Supervised Learning : I/P -> train the model -> find the o/p
#     Classification
#     Image Classification (male / female, cancer detection , object detection )
#     Regression:  1900 - 2022
#     Forecasting Weather
#     Market forecasting
#     Population growth prediction
# Unsupervised Learning :
#     Clustering
#     Amazon Recommendation
#     Google recommendation
#     Dimensionality Reduction
#     Implemented in 3 ways:
#     Principal Component Analysis
#     Factor analysis
#     Correspondence analysis
#     Eg: Columns 10k -> Column 5
#     Big Data Visualise
# Reinforcement Learning:
#     Robot Navigation
#     Self Driving car - Traffic signal -> red(behind , front , apply brake), green , orange (car ,behind , front , move)

# %% [markdown]
# Qualitative Examples of Machine Learning Applications
# 1.Classification problem - Predicting discrete labels
#
# I/p : Dataset - > Labeled set
# O/P : Classify the unlabeled set
#
# eg: Label -> Blue , red
#
# Sln ->
#
# Method 1: By using Algorithm :
#
# 1.Naive Bayes Classification algo
# 2.Support Vector Machine (SVM)
# 3.Decision Tree
# 4.Random Forest
#
# Method 2:
#
# Deep learning -> DNN, ANN, RNN
# Model -> Mobilenet , Retinanet etc...
# Google tensorflow , AWS , Microsoft azure , Opencv

# %%
#Implemetation
from sklearn.datasets import make_blobs
from sklearn.svm import SVC # Support Vector Classifier model
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#Binary Large Object
X, y = make_blobs(n_samples=50, centers=2,
                  random_state=0, cluster_std=0.60) 
#Fitting the svc m
clf=SVC(kernel='linear')
clf.fit(X,y)

#creating new points to predict 
X2, _ = make_blobs(n_samples=80, centers=2,
                   random_state=0, cluster_std=0.80)

X2 = X2[50:] 
#Predict
y2=clf.predict(X2)

#Visualization
fig, ax = plt.subplots(figsize=(8, 6))
point_style = dict(cmap='Paired', s=50)
ax.scatter(X[:, 0], X[:, 1], c=y, **point_style)

# %%
#Visualization 2

xx = np.linspace(-1, 4, 10)
yy = np.linspace(-2, 7, 10)
xy1, xy2 = np.meshgrid(xx, yy)
Z = np.array([clf.decision_function([t])
              for t in zip(xy1.flat, xy2.flat)]).reshape(xy1.shape)

# plot points and model
fig, ax = plt.subplots(figsize=(8, 6))
line_style = dict(levels = [-1.0, 0.0, 1.0],
                  linestyles = ['dashed', 'solid', 'dashed'],
                  colors = 'gray', linewidths=1)
ax.scatter(X[:, 0], X[:, 1], c=y, **point_style)
ax.contour(xy1, xy2, Z, **line_style)

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)

ax[0].scatter(X2[:, 0], X2[:, 1], c='gray', **point_style)
ax[0].axis([-1, 4, -2, 7])

ax[1].scatter(X2[:, 0], X2[:, 1], c=y2, **point_style)
ax[1].contour(xy1, xy2, Z, **line_style)
ax[1].axis([-1, 4, -2, 7])
# Out:
# C:\Users\bjawa\AppData\Local\Temp\ipykernel_13744\3966486398.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax[0].scatter(X2[:, 0], X2[:, 1], c='gray', **point_style)
# (-1.0, 4.0, -2.0, 7.0)

# %% [markdown]
# SVM :
#     Hyperplane -> line
#     1.Linear  -> data in linear way
#     2.Non Linear   -> Non linear way (U cannot draw a hyper plan)

# %%
#Regression -Predicting continuous labels

from sklearn.linear_model import LinearRegression
#Dataset creation
rng = np.random.RandomState(1)
X = rng.randn(200, 2)
y = np.dot(X, [-2, 1]) + 0.1 * rng.randn(X.shape[0])

#regression fit

model = LinearRegression()
model.fit(X, y)

#New dataset 
X2 = rng.randn(100, 2)

#predict 

y2 = model.predict(X2)

#visualization

fig, ax = plt.subplots()
points = ax.scatter(X[:, 0], X[:, 1], c=y, s=50,
                    cmap='viridis')

# %%
#visu 2
from matplotlib.collections import LineCollection

fig, ax = plt.subplots()
pts = ax.scatter(X[:, 0], X[:, 1], c=y, s=50,
                 cmap='viridis', zorder=2)
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)

ax[0].scatter(X2[:, 0], X2[:, 1], c='gray', s=50)
ax[0].axis([-4, 4, -3, 3])

ax[1].scatter(X2[:, 0], X2[:, 1], c=y2, s=50,
              cmap='viridis', norm=pts.norm)
ax[1].axis([-4, 4, -3, 3])
# Out:
# (-4.0, 4.0, -3.0, 3.0)

# %%
#Clustering
#1.Kmeans
#2.Gauusian Mixture ALgo
#3.Scikit learn clustering algo

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
#creating a dataset 
X, y = make_blobs(n_samples=100, centers=4,
                  random_state=42, cluster_std=1.5)
#fit the kmeans
model = KMeans(4, random_state=0)

#predict
y = model.fit_predict(X)

#visual
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(X[:, 0], X[:, 1], s=50, color='gray')
# Out:
# C:\Users\bjawa\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#Dimensionality reduction- 

from sklearn.datasets import make_swiss_roll

# make data
X, y = make_swiss_roll(200, noise=0.5, random_state=42)
X = X[:, [0, 2]]

# visualize data
fig, ax = plt.subplots()
ax.scatter(X[:, 0], X[:, 1], color='gray', s=30)

# %%
from sklearn.manifold import Isomap

model = Isomap(n_neighbors=8, n_components=1)
y_fit = model.fit_transform(X).ravel()

# visualize data
fig, ax = plt.subplots()
pts = ax.scatter(X[:, 0], X[:, 1], c=y_fit, cmap='viridis', s=30)
cb = fig.colorbar(pts, ax=ax)

# %% [markdown]
# #EG:
#
# File --> Limit 1mb -> 2mb > Compressing  -> DR

# %% [markdown]
# Introducing Scikit-Learn
#     Data Representation in Scikit-Learn
# 	Scikit-Learn’s Estimator API
# 	Application: Exploring Handwritten Digits

# %%
#Data Representation in Scikit-Learn
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #Scikit-Learn's Estimator API
#
# 1.import scikit
# 2.choose hyperparameters
# 3.Arrange or undert i/p &o/p
# 4. fit to model
# 5.predit , transfor()

# %%
#classification . iris
from sklearn.model_selection import train_test_split
X_iris = iris.drop('species', axis=1)
y_iris = iris['species']
x_train, Xtest, y_train, ytest = train_test_split(X_iris, y_iris,
                                                random_state=1)
from sklearn.naive_bayes import GaussianNB

#fit
model = GaussianNB()
model.fit(x_train, y_train) 

#predit
y_model = model.predict(Xtest) 

#acc
from sklearn.metrics import accuracy_score
a=accuracy_score(ytest, y_model)
print(a)
# Out:
# 0.9736842105263158
