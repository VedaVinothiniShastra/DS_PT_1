# %% [markdown]
# I/P : [1,7,4,8,3,4,4,5,5,5,5,5]
# O/P :
# 5
# [1,3,4,5,7,8] --> Unique values  , Sorted format

# %%
deletedup(n1,A1):
    t=sorted(set(A1)) #--> Sorted &Remove the dup  --> [1,3,4,5,7,8]
    r=len(t) #->5
    print(r)
    print(t)   
    
n=[1,7,4,8,3,4,4,5,5,5,5,5] #-> raw_input()
A=[] #-> Count of unique value  
deletedup(n,A)

# %%
def deleteDuplicate(N,A):
    #this is default OUTPUT. You can change it
    s=sorted(set(A)) 
    result = len(s)
  
    # WRITE YOUR LOGIC HERE:
    
    
    #For optimizing code, You are free to make changes to "return type", "variables" and "Libraries".
    print result
    for i in s:
        print i, 

#INPUT [uncomment & modify if required]
temp = raw_input().split(',') 

N = int(temp[0])
A = []
temp1 = raw_input().split()
for i in xrange(N):
    A.append(int(temp1[i])) 

#OUTPUT [uncomment & modify if required]
deleteDuplicate(N,A)

# Test 3 cases - > pass -. 100%
